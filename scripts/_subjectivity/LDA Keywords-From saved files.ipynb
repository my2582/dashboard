# %% [markdown]
# ## Dashborad information
# - Tab: Sentiment

# %% [markdown]
# ## Code information
# - Original author: Kevin Choi
# - Author: Minsu Yeom
# - Description: by loading three saved files, namely a dictionary, corpus and model result, reproduce what the original author called 'vis' to deploy on a dashboard.
# - Date: March 7, 2019

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import pickle

# %%
dictionary = gensim.corpora.Dictionary.load('id2word.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model.gensim')
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# /Users/msyeom/anaconda3/envs/qgr/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el241801125340110006983598825"></div>
# <script type="text/javascript">
#
# ...

# %%
lda_display
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.000287  0.000868       1        1  15.231290
# 1     -0.000634 -0.000391       2        1  19.691073
# 2     -0.000384  0.000286       3        1   9.163223
# 3      0.000381 -0.000511       4        1  14.234028
# 4     -0.000172  0.000072       5        1  10.296358
# 5      0.001035 -0.000125       6        1  10.800110
# 6     -0.000171 -0.000693       7        1  11.492958
# 7     -0.000343  0.000494       8        1   9.090960, topic_info=      Category       Freq                                               Term  \
# 23848  Default  55.000000                       china investment corporation
# 11464  Default  51.000000                                             warbug
# 32684  Default  58.000000                         the u s japan south africa
# 3193   Default  53.000000                                        contributor
# ...
